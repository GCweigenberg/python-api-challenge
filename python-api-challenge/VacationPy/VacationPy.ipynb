# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import pandas
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_key import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      Butaritari   3.0707  172.7902     81.66        77          89
# 1        1      Chokurdakh  70.6333  147.9167    -23.19        99          98
# 2        2      Porto Novo   6.4965    2.6036     79.57        81          80
# 3        3         Ushuaia -54.8000  -68.3000     44.26        76         100
# 4        4  Iroquois Falls  48.7669  -80.6831      5.16        92          17
#
#    Wind Speed Country        date
# 0       16.64      KI  1670539997
# 1        4.56      RU  1670539998
# 2        5.61      BJ  1670539998
# 3       13.80      AR  1670539745
# 4        2.44      CA  1670539999

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 city_data_df = types_df.drop(columns=["Unnamed: 0"])
#       2 city_data_df
#
# NameError: name 'types_df' is not defined

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
humid_map_plot = city_data_df.hvplot.points(
    "Humidity"
    geo = True,
    tiles = "Humid Map",
    frame_width = 800,
    frame_height = 600    
)

# Display the map plot
humid_map_plot

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
narrow_city_df = city_data_df.loc[(city_data_df["Wind Speed"] <= 14) & (city_data_df["Cloudiness"] == 0) & \
                                   (city_data_df["Max Temp"] >= 75) & (city_data_df["Max Temp"] <= 90)].dropna()

narrow_city_df

# Drop any rows with null values


# Display sample data
# YOUR CODE HERE
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 59        59           Mar Del Plata -38.0023  -57.5575     78.82        27
# 87        87                     Vao -22.6667  167.4833     78.21        80
# 93        93               Cape Town -33.9258   18.4232     76.37        61
# 99        99                 Bubaque  11.2833  -15.8333     81.16        71
# 128      128             Saint-Louis  16.3333  -15.0000     82.04        34
# 141      141                   Kolda  12.8833  -14.9500     77.31        88
# 153      153                 Cayenne   4.9333  -52.3333     77.04        94
# 233      233                 Solenzo  12.1833   -4.0833     77.95        20
# 249      249        Puerto Escondido  15.8500  -97.0667     81.59        64
# 269      269          Tarpon Springs  28.1461  -82.7568     76.14        81
# 289      289              Rio Grande -32.0350  -52.0986     80.71        83
# 293      293            Raymondville  26.4815  -97.7831     82.51        46
# 347      347         Delta Del Tigre -34.7633  -56.3853     88.21        45
# 366      366                    Buin -33.7333  -70.7500     88.02        34
# 368      368              Valparaiso -33.0393  -71.6273     75.43        85
# 376      376                Acapulco  16.8634  -99.8901     82.15        69
# 403      403            San Patricio  28.0170  -97.5169     79.54        71
# 418      418                Pochutla  15.7432  -96.4661     85.82        61
# 450      450               Roebourne -20.7833  117.1333     81.81        39
# 452      452                Oussouye  12.4850  -16.5469     77.18        82
# 550      550  Sao Francisco De Assis -29.5503  -55.1311     87.31        26
#
#      Cloudiness  Wind Speed Country        date
# 59            0       10.36      AR  1670540020
# 87            0        8.03      NC  1670540029
# 93            0        6.91      ZA  1670539937
# 99            0       13.09      GW  1670540033
# 128           0       12.10      SN  1670539878
# 141           0        0.00      SN  1670540050
# 153           0        0.00      GF  1670539861
# 233           0        7.09      BF  1670540087
# 249           0        5.14      MX  1670540093
# 269           0        6.91      US  1670539876
# 289           0       12.24      BR  1670540113
# 293           0       13.47      US  1670540115
# 347           0        4.61      UY  1670540139
# 366           0        9.75      CL  1670540146
# 368           0       13.80      CL  1670539895
# 376           0        7.63      MX  1670540150
# 403           0       11.34      US  1670540160
# 418           0        5.88      MX  1670540171
# 450           0       13.18      AU  1670540184
# 452           0        5.55      SN  1670540184
# 550           0        7.29      BR  1670540226

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrow_city_df.loc[:,["City","Country", "Lat", "Lng"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                        City Country      Lat       Lng Hotel Name
# 59            Mar Del Plata      AR -38.0023  -57.5575
# 87                      Vao      NC -22.6667  167.4833
# 93                Cape Town      ZA -33.9258   18.4232
# 99                  Bubaque      GW  11.2833  -15.8333
# 128             Saint-Louis      SN  16.3333  -15.0000
# 141                   Kolda      SN  12.8833  -14.9500
# 153                 Cayenne      GF   4.9333  -52.3333
# 233                 Solenzo      BF  12.1833   -4.0833
# 249        Puerto Escondido      MX  15.8500  -97.0667
# 269          Tarpon Springs      US  28.1461  -82.7568
# 289              Rio Grande      BR -32.0350  -52.0986
# 293            Raymondville      US  26.4815  -97.7831
# 347         Delta Del Tigre      UY -34.7633  -56.3853
# 366                    Buin      CL -33.7333  -70.7500
# 368              Valparaiso      CL -33.0393  -71.6273
# 376                Acapulco      MX  16.8634  -99.8901
# 403            San Patricio      US  28.0170  -97.5169
# 418                Pochutla      MX  15.7432  -96.4661
# 450               Roebourne      AU -20.7833  117.1333
# 452                Oussouye      SN  12.4850  -16.5469
# 550  Sao Francisco De Assis      BR -29.5503  -55.1311

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel

filters = f"circle:{lng},{lat},{radius}"
bias = f"proximity:{lng},{lat}"
params = {
    "radius": 5000,
    "types": "hotel",
    "keyword": "hotel",
    "apiKey":geoapify_key  
}

# %%
# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# %%
# filters = f"circle:{lng},{lat},{radius}"
# bias = f"proximity:{lng},{lat}"
#

# %%
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
            lat = row["Lat"]
            lng = row["Lng"]
          
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
            params["location"] = f"{lat},{lng}"
           
    # Make an API request using the params dictionaty
            
            name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
            name_address = name_address.json() 
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
            try:
                hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
            except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
                hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
                print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Mar Del Plata - nearest hotel: No hotel found
# Vao - nearest hotel: No hotel found
# Cape Town - nearest hotel: No hotel found
# Bubaque - nearest hotel: No hotel found
# Saint-Louis - nearest hotel: No hotel found
# Kolda - nearest hotel: No hotel found
# Cayenne - nearest hotel: No hotel found
# Solenzo - nearest hotel: No hotel found
# Puerto Escondido - nearest hotel: No hotel found
# Tarpon Springs - nearest hotel: No hotel found
# Rio Grande - nearest hotel: No hotel found
# Raymondville - nearest hotel: No hotel found
# Delta Del Tigre - nearest hotel: No hotel found
# Buin - nearest hotel: No hotel found
# Valparaiso - nearest hotel: No hotel found
# Acapulco - nearest hotel: No hotel found
# San Patricio - nearest hotel: No hotel found
# Pochutla - nearest hotel: No hotel found
# Roebourne - nearest hotel: No hotel found
# Oussouye - nearest hotel: No hotel found
# Sao Francisco De Assis - nearest hotel: No hotel found
#                        City Country      Lat       Lng      Hotel Name
# 59            Mar Del Plata      AR -38.0023  -57.5575  No hotel found
# 87                      Vao      NC -22.6667  167.4833  No hotel found
# 93                Cape Town      ZA -33.9258   18.4232  No hotel found
# 99                  Bubaque      GW  11.2833  -15.8333  No hotel found
# 128             Saint-Louis      SN  16.3333  -15.0000  No hotel found
# 141                   Kolda      SN  12.8833  -14.9500  No hotel found
# 153                 Cayenne      GF   4.9333  -52.3333  No hotel found
# 233                 Solenzo      BF  12.1833   -4.0833  No hotel found
# 249        Puerto Escondido      MX  15.8500  -97.0667  No hotel found
# 269          Tarpon Springs      US  28.1461  -82.7568  No hotel found
# 289              Rio Grande      BR -32.0350  -52.0986  No hotel found
# 293            Raymondville      US  26.4815  -97.7831  No hotel found
# 347         Delta Del Tigre      UY -34.7633  -56.3853  No hotel found
# 366                    Buin      CL -33.7333  -70.7500  No hotel found
# 368              Valparaiso      CL -33.0393  -71.6273  No hotel found
# 376                Acapulco      MX  16.8634  -99.8901  No hotel found
# 403            San Patricio      US  28.0170  -97.5169  No hotel found
# 418                Pochutla      MX  15.7432  -96.4661  No hotel found
# 450               Roebourne      AU -20.7833  117.1333  No hotel found
# 452                Oussouye      SN  12.4850  -16.5469  No hotel found
# 550  Sao Francisco De Assis      BR -29.5503  -55.1311  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
